# %%
import os
import shutil
import glob
from tqdm import tqdm

# %% [markdown]
# # subject ID: xxx
#
# image number: xxx
#
# gender: 0 - male 1 - famale
#
# glasses: 0 - no 1 - yes
#
# eye state: 0 - close 1 - open
#
# reflections: 0 - none 1 - low 2 - high
#
# lighting conditions/image quality: 0 - bad 1 - good
#
# sensor type: 01 - RealSense SR300 640x480 02 - IDS Imaging, 1280x1024 03 - Aptina Imagin 752x480
#
# example: s001_00123_0_0_0_0_0_01.png

# %%
Raw_Dir = r'C:\Users\HP\OneDrive\Desktop\Deep learning\mrlEyes_2018_01'

for dirpath, dirname, filenames in os.walk(Raw_Dir):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        status = i.split('_')[4]  # Correct index for the status part based on filename structure

        if status == '0':
            shutil.copy(src=os.path.join(dirpath, i), dst=r'C:\Users\HP\OneDrive\Desktop\Deep learning\prepared_Data\Close_Eyes')
        elif status == '1':
            shutil.copy(src=os.path.join(dirpath, i), dst=r'C:\Users\HP\OneDrive\Desktop\Deep learning\prepared_Data\Open_Eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [03:37<00:00, 47.14it/s]

# %%
i='s0001_00013_0_0_0_0_0_01'

# %%
i.split('_')[4]
# Out:
# '0'
